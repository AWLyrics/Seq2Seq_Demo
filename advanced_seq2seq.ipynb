# %%
import numpy as np
import tensorflow as tf
from  tensorflow.keras.preprocessing.sequence import pad_sequences

# %% [markdown]
# # Advanced Seq2Seq
#
# ## Problems of Naive Seq2Seq
#
# 之前的 Seq2Seq 我们会在每次都把 ground truth 喂给 Seq2Seq 中的 encoder, 但事实上, **decoder 应该依赖自己前面产生的 token 来进行下一个 token 的生成。这样才能在 inference 阶段自主地产生一些句子，因为 inference 阶段是没有 ground truth 的**
#
#
# ## Implementation
# 这个代码就是实现了在 decode 阶段用 decoder 产生的 ** previous state, previous prediction 来进行下一个 token 的预测**。主要使用了 `tf.nn.raw_rnn` 接口来实现，可以自定义一个 loop_function 控制 RNN 的循环。
# 但是存在一个问题，即使在 test 阶段不再需要 ground truth, 但需要我们提供需要产生的序列长度才能进行 test，可以进一步进行优化（自定义 RNN cell，并且加入长度相关的 mask），使得在 inference 阶段只需要 encoder 端的信息就能够产生歌词。
#
#
# ## Result Comparison
# 通过和 Naive Seq2Seq 的对比，可以看到在相同的步数（1000），Naive Seq2Seq 已经能够完全正确预测下一句歌词，但是 Advanced Seq2Seq 不行，因为 **自己产生的token** 很有可能是不对的，前一步的错误会导致后面的崩坏。
#
# ## Optimization
# 进一步地优化方向主要有三个：
# 1. 增大数据集，只有一首歌词，仅仅是个 toy model
# 2. 加入 Attention 机制，具体就是在 decoder 阶段可以考虑对 encoder 的 outputs 进行 Attention 操作
# 3. 加入 [Scheduled Sampling](https://arxiv.org/abs/1506.03099)

# %%
# load dataset
x = []
y =[]
i = 0
with open("time.txt", "r") as f:
    for l in f:
        if i % 2 == 0:
            x.append(l.strip())
        else:
            y.append(l.strip())
        i+=1

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
import jieba
# Tokenizer 
tokenizer = Tokenizer(oov_token='<UNK>')
words = []
for s in x:
    words.extend(jieba.cut(s))
for s in y:
    words.extend(jieba.cut(s))
    
tokenizer.fit_on_texts(words)
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache /var/folders/0l/3x73_lfs6czgjngbxbtn1vrh0000gn/T/jieba.cache
# Loading model cost 0.893 seconds.
# Prefix dict has been built succesfully.

# %%
from tensorflow.contrib.rnn import LSTMCell, LSTMStateTuple

# %%
train = []
for s in x:
    xx = tokenizer.texts_to_sequences(list(jieba.cut(s)))
#     print(list(jieba.cut(s)))
#     print(s)
    if len(xx) > 0:
        idx = [ xxx[0] for xxx in xx if xxx != []]
        train.append(idx)
test = []
for s in y:
    xx = tokenizer.texts_to_sequences(list(jieba.cut(s)))
#     print(list(jieba.cut(s)))
#     print(s)
    if len(xx) > 0:
        idx = [ xxx[0] for xxx in xx if xxx != []]
        test.append(idx)

# %%
vocab_size = len(tokenizer.word_docs) + 2 # pad + eos

# %%
input_embedding_size = 16

encoder_hidden_units = 8
decoder_hidden_units = encoder_hidden_units * 2

graph = tf.Graph()
with graph.as_default():
    encoder_inputs = tf.placeholder(shape=(None, None), dtype=tf.int32, name='encoder_inputs')
    encoder_inputs_length = tf.placeholder(shape=(None,), dtype=tf.int32, name='encoder_inputs_length')

    decoder_targets = tf.placeholder(shape=(None, None), dtype=tf.int32, name='decoder_targets')
    decoder_lengths = tf.placeholder(shape=(None,), dtype=tf.int32, name='decoder_targets_length')
    
    embeddings = tf.Variable(tf.random_uniform([vocab_size, input_embedding_size], -1.0, 1.0), dtype=tf.float32)

    encoder_inputs_embedded = tf.nn.embedding_lookup(embeddings, encoder_inputs)
    with tf.name_scope("encoder"):
        encoder_cell = LSTMCell(encoder_hidden_units)

        ((encoder_fw_outputs,
      encoder_bw_outputs), 
         (encoder_fw_final_state,
      encoder_bw_final_state)) = (
        tf.nn.bidirectional_dynamic_rnn(cell_fw=encoder_cell,
                                        cell_bw=encoder_cell,
                                        inputs=encoder_inputs_embedded,
                                        sequence_length=encoder_inputs_length,
                                        dtype=tf.float32, time_major=True)
        )
    
        # concaten fw and bw outputs
        encoder_outputs = tf.concat((encoder_fw_outputs, encoder_bw_outputs), 2)
        # concaten fw and bw state_c
        encoder_final_state_c = tf.concat(
            (encoder_fw_final_state.c, encoder_bw_final_state.c), 1)
        # # concaten fw and bw state_h
        encoder_final_state_h = tf.concat(
            (encoder_fw_final_state.h, encoder_bw_final_state.h), 1)
        # format as LSTMStateTuple
        encoder_final_state = LSTMStateTuple(
            c=encoder_final_state_c,
            h=encoder_final_state_h
        )
        
    with tf.name_scope("decoder"):
        decoder_cell = LSTMCell(decoder_hidden_units)
        encoder_max_time, batch_size = tf.unstack(tf.shape(encoder_inputs))
        # not sure
#         decoder_lengths = encoder_inputs_length + 3 # +2 additional steps, +1 leading <EOS> token for decoder inputs
    with tf.name_scope("output"):
        W = tf.Variable(tf.random_uniform([decoder_hidden_units, vocab_size], -1, 1), dtype=tf.float32)
        b = tf.Variable(tf.zeros([vocab_size]), dtype=tf.float32)
    
    # assert EOS == 1 and PAD == 0

    eos_time_slice = tf.zeros([batch_size], dtype=tf.int32, name='EOS')
#     pad_time_slice = tf.zeros([batch_size], dtype=tf.int32, name='PAD')

    eos_step_embedded = tf.nn.embedding_lookup(embeddings, eos_time_slice)
#     pad_step_embedded = tf.nn.embedding_lookup(embeddings, pad_time_slice)
    
    # Loop transition function is a mapping (time, previous_cell_output, previous_cell_state, previous_loop_state)
    #               ->     (elements_finished, input, cell_state, output, loop_state).
    def loop_fn_initial():
        initial_elements_finished = (0 >= decoder_lengths)  # all False at the initial step
        initial_input = eos_step_embedded
        initial_cell_state = encoder_final_state
        initial_cell_output = None
        initial_loop_state = None  # we don't need to pass any additional information
        return (initial_elements_finished,
                initial_input,
                initial_cell_state,
                initial_cell_output,
                initial_loop_state)
    
    def loop_fn_transition(time, previous_output, previous_state, previous_loop_state):

        def get_next_input():
            # Wx + b -> logits
            output_logits = tf.add(tf.matmul(previous_output, W), b)
            prediction = tf.argmax(output_logits, axis=1)
            next_input = tf.nn.embedding_lookup(embeddings, prediction)
            return next_input

        elements_finished = (time >= decoder_lengths) # this operation produces boolean tensor of [batch_size]
                                                      # defining if corresponding sequence has ended

        finished = tf.reduce_all(elements_finished) # -> boolean scalar
        input = tf.cond(finished, lambda: eos_step_embedded, get_next_input) # if finished, then return pad_step_embeded
        state = previous_state
        output = previous_output
        loop_state = None

        return (elements_finished, 
                input,
                state,
                output,
                loop_state)
    def loop_fn(time, previous_output, previous_state, previous_loop_state):
        if previous_state is None:    # time == 0
            assert previous_output is None and previous_state is None
            return loop_fn_initial()
        else:
            return loop_fn_transition(time, previous_output, previous_state, previous_loop_state)

    decoder_outputs_ta, decoder_final_state, _ = tf.nn.raw_rnn(decoder_cell, loop_fn)
    decoder_outputs = decoder_outputs_ta.stack()
    print(decoder_outputs) # [max_steps, batch_size, hidden_dim] 
    
    # flatten outputs to [max_steps * batch_sizes, hidden_dim]
    decoder_max_steps, decoder_batch_size, decoder_dim = tf.unstack(tf.shape(decoder_outputs))
    decoder_outputs_flat = tf.reshape(decoder_outputs, (-1, decoder_dim))
    # logits = Wx+ b
    decoder_logits_flat = tf.add(tf.matmul(decoder_outputs_flat, W), b)
    print(decoder_logits_flat.shape)
    # reshape back to [max_step, batch_size, vocab]
    decoder_logits = tf.reshape(decoder_logits_flat, (decoder_max_steps, decoder_batch_size, vocab_size))
    # get prediction
    decoder_prediction = tf.argmax(decoder_logits, 2)
    print(decoder_targets.shape) # 
    print(vocab_size)
    print(decoder_logits.shape)
    # logits_size=[338,210] labels_size=[364,210] 
    print(tf.one_hot(decoder_targets, depth=vocab_size, dtype=tf.float32))
    stepwise_cross_entropy = tf.nn.softmax_cross_entropy_with_logits_v2(
    labels=tf.one_hot(decoder_targets, depth=vocab_size, dtype=tf.float32),
    logits=decoder_logits,
)

    loss = tf.reduce_mean(stepwise_cross_entropy)
    train_op = tf.train.AdamOptimizer().minimize(loss)
# Out:
# Tensor("TensorArrayStack/TensorArrayGatherV3:0", shape=(?, ?, 16), dtype=float32)
# (?, 210)
# (?, ?)
# 210
# (?, ?, 210)
# Tensor("one_hot:0", shape=(?, ?, 210), dtype=float32)

# %%
def batch(inputs, max_sequence_length=None):
    """
    Args:
        inputs:
            list of sentences (integer lists)
        max_sequence_length:
            integer specifying how large should `max_time` dimension be.
            If None, maximum sequence length would be used
    
    Outputs:
        inputs_time_major:
            input sentences transformed into time-major matrix 
            (shape [max_time, batch_size]) padded with 0s
        sequence_lengths:
            batch-sized list of integers specifying amount of active 
            time steps in each input sequence
    """
    
    sequence_lengths = [len(seq) for seq in inputs]
    batch_size = len(inputs)
    
    if max_sequence_length is None:
        max_sequence_length = max(sequence_lengths)
    
    inputs_batch_major = np.zeros(shape=[batch_size, max_sequence_length], dtype=np.int32) # == PAD
    
    for i, seq in enumerate(inputs):
        for j, element in enumerate(seq):
            inputs_batch_major[i, j] = element

    # [batch_size, max_time] -> [max_time, batch_size]
    inputs_time_major = inputs_batch_major.swapaxes(0, 1)

    return inputs_time_major, sequence_lengths

# %%
train_time, train_lengths = batch(train)

# %%
print(train_time.shape)
print(max(train_lengths))
# Out:
# (10, 26)
# 10

# %%
test_time, test_lengths = batch(test)
print(test_time.shape)
print(max(test_lengths))
# Out:
# (11, 26)
# 11

# %%
PAD = 0
EOS = len(tokenizer.word_index) + 1
test_targets_, _ = batch(
        [(sequence)  for sequence in test]
    )

# %%
print(test_targets_.shape)
# Out:
# (11, 26)

# %%
word2idx = tokenizer.word_index
id2word = {k: v for v, k in zip(word2idx.keys(), word2idx.values())}
def translate(word_indexs):
    words = []
    for idx in word_indexs:
        word = id2word.get(idx)
#         print(word)
        if word:
            words.append(id2word.get(idx))
        else:
            words.append("<UNK>")
    return "".join(words)

# %%
import random

epochs = 10000

with tf.Session(graph=graph) as sess:
    sess.run(tf.global_variables_initializer())
    for e in range(epochs):
        l, _ = sess.run([loss, train_op], feed_dict={
                encoder_inputs: train_time,
                encoder_inputs_length: train_lengths,
                decoder_targets: test_targets_,
                decoder_lengths: test_lengths
        })
#         print(l)
        if e % 50 == 0:
    
            pred = sess.run(decoder_prediction, feed_dict={
                encoder_inputs: train_time,
                encoder_inputs_length: train_lengths,
#                 decoder_targets: test_targets_,
                decoder_lengths: [ i + 1 for i in train_lengths]
            })
            
#             print(translate(np.transpose(pred)[0]))

            rand_idx = (int) (random.random() * (train_time.shape[1]) )
            print("epoch: %d loss : %f" %( e, l))
            print("input: ", translate(np.transpose(train_time)[rand_idx]))
            print("predict: ", translate(np.transpose(pred)[rand_idx]))
            print("ground truth: ",translate(np.transpose(test_time)[rand_idx]) )
            print("-----------------------------------------")
#             print("Input: ")
# Out:
# epoch: 0 loss : 5.367332
# input:  我发现我早已经长大<UNK><UNK><UNK><UNK>
# predict:  尽如刀尽如刀如刀独自如刀<UNK><UNK><UNK><UNK>
# ground truth:  我发现我早不说谎话<UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 50 loss : 5.194360
# input:  我渐渐长大成人<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# predict:  起跑的hiphip时间时间时间时间时间时间时间
# ground truth:  眼看着世界沉沦<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 100 loss : 4.877698
# input:  脱掉了曾经<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# predict:  母亲的的的时间时间时间时间时间时间时间
# ground truth:  认为很时尚的大肥裤子<UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 150 loss : 4.447875
# input:  我闭上双眼祈祷<UNK><UNK><UNK><UNK><UNK><UNK>
# predict:  我我我以前忘时间时间时间时间时间时间
# ground truth:  我知道努力学习以后才能把歌写好<UNK><UNK>
# -----------------------------------------
# epoch: 200 loss : 4.064038
# input:  经典的就像是oldschoolflow<UNK><UNK><UNK>
# predict:  从从质疑质疑质疑质疑质疑质疑时间时间时间
# ground truth:  从不用质疑<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 250 loss : 3.731657
# input:  我也不再年幼<UNK><UNK><UNK><UNK><UNK><UNK>
# predict:  那些做我的的<UNK><UNK><UNK><UNK><UNK><UNK>
# ground truth:  那些年做过的课间操<UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 300 loss : 3.424516
# input:  所以我努力的跑<UNK><UNK><UNK><UNK><UNK>
# predict:  把把我我看透看透<UNK><UNK><UNK><UNK><UNK>
# ground truth:  把一切全部看透<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 350 loss : 3.221731
# input:  那心酸的滋味我只能独自体会<UNK><UNK>
# predict:  想要回到回到但是时光倒退倒退倒退倒退<UNK><UNK>
# ground truth:  想要回到过去但是时光不能倒退<UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 400 loss : 3.038214
# input:  脱掉了曾经<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# predict:  认为时尚认为的<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# ground truth:  认为很时尚的大肥裤子<UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 450 loss : 2.837336
# input:  脱掉了曾经<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# predict:  认为时尚时尚的<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# ground truth:  认为很时尚的大肥裤子<UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 500 loss : 2.680605
# input:  脱掉了曾经<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# predict:  认为很时尚的<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# ground truth:  认为很时尚的大肥裤子<UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 550 loss : 2.577763
# input:  再没骗自己的理由<UNK><UNK><UNK><UNK><UNK>
# predict:  时间如刀不再温柔温柔如刀<UNK><UNK><UNK><UNK><UNK>
# ground truth:  时间如刀不再温柔<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 600 loss : 2.447405
# input:  街边的落日和小时候的复读机<UNK><UNK><UNK>
# predict:  度过了但我我要以前出息<UNK><UNK><UNK>
# ground truth:  度过了末日但我要比以前有出息<UNK>
# -----------------------------------------
# epoch: 650 loss : 2.348726
# input:  再没骗自己的理由<UNK><UNK><UNK><UNK><UNK>
# predict:  时间如刀不再温柔温柔如刀<UNK><UNK><UNK><UNK><UNK>
# ground truth:  时间如刀不再温柔<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 700 loss : 2.246931
# input:  特别的怀念<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# predict:  回到童年童年童年<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# ground truth:  回到童年<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 750 loss : 2.147089
# input:  经典的就像是oldschoolflow<UNK><UNK><UNK>
# predict:  从不用质疑质疑质疑质疑质疑回不去<UNK><UNK><UNK>
# ground truth:  从不用质疑<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 800 loss : 2.066952
# input:  我也不再年幼<UNK><UNK><UNK><UNK><UNK><UNK>
# predict:  那些年做过的<UNK><UNK><UNK><UNK><UNK><UNK>
# ground truth:  那些年做过的课间操<UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 850 loss : 1.981231
# input:  不用问我的来路<UNK><UNK><UNK><UNK><UNK>
# predict:  贫民窟的艺术家艺术家的手<UNK><UNK><UNK><UNK><UNK>
# ground truth:  贫民窟的艺术家<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 900 loss : 1.903819
# input:  到现在<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# predict:  我依旧做<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# ground truth:  我依旧做说唱还在饿着肚子<UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 950 loss : 1.831501
# input:  我渐渐长大成人<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# predict:  眼看着世界沉沦<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# ground truth:  眼看着世界沉沦<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 1000 loss : 1.764339
# input:  街边的落日和小时候的复读机<UNK><UNK><UNK>
# predict:  度过了末日但我要比以前<UNK><UNK><UNK>
# ground truth:  度过了末日但我要比以前有出息<UNK>
# -----------------------------------------
# epoch: 1050 loss : 1.701081
# input:  街边的落日和小时候的复读机<UNK><UNK><UNK>
# predict:  度过了末日但我要比以前<UNK><UNK><UNK>
# ground truth:  度过了末日但我要比以前有出息<UNK>
# -----------------------------------------
# epoch: 1100 loss : 1.641058
# input:  校门口美味的路边摊还在不在<UNK><UNK>
# predict:  包里塞的小吃那是外婆给的<UNK><UNK>
# ground truth:  包里塞的小吃那是外婆给的爱<UNK>
# -----------------------------------------
# epoch: 1150 loss : 1.584395
# input:  小霸王游戏机<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# predict:  陪我度过<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# ground truth:  陪我度过了一段时期<UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 1200 loss : 1.529491
# input:  经典的就像是oldschoolflow<UNK><UNK><UNK>
# predict:  从不用质疑质疑质疑质疑回不去的<UNK><UNK><UNK>
# ground truth:  从不用质疑<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 1250 loss : 1.476428
# input:  我渐渐长大成人<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# predict:  眼看着世界沉沦<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# ground truth:  眼看着世界沉沦<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 1300 loss : 1.425482
# input:  我发现我早已经长大<UNK><UNK><UNK><UNK>
# predict:  我发现我早不说谎话<UNK><UNK><UNK><UNK>
# ground truth:  我发现我早不说谎话<UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 1350 loss : 1.376052
# input:  我也不再年幼<UNK><UNK><UNK><UNK><UNK><UNK>
# predict:  那些年做过的<UNK><UNK><UNK><UNK><UNK><UNK>
# ground truth:  那些年做过的课间操<UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 1400 loss : 1.327997
# input:  再没骗自己的理由<UNK><UNK><UNK><UNK><UNK>
# predict:  时间如刀不再温柔温柔如刀<UNK><UNK><UNK><UNK><UNK>
# ground truth:  时间如刀不再温柔<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 1450 loss : 1.281177
# input:  再没骗自己的理由<UNK><UNK><UNK><UNK><UNK>
# predict:  时间如刀不再温柔温柔如刀<UNK><UNK><UNK><UNK><UNK>
# ground truth:  时间如刀不再温柔<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 1500 loss : 1.235491
# input:  街边的落日和小时候的复读机<UNK><UNK><UNK>
# predict:  度过了末日但我要比以前<UNK><UNK><UNK>
# ground truth:  度过了末日但我要比以前有出息<UNK>
# -----------------------------------------
# epoch: 1550 loss : 1.190903
# input:  我想让我爱的人过的更好
# predict:  所以才去战斗战斗战斗战斗战斗战斗<UNK>那双
# ground truth:  所以才去战斗<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 1600 loss : 1.147382
# input:  一路走汗在流再回首已没有<UNK><UNK>
# predict:  那双扶着我不跌倒的手<UNK><UNK><UNK>
# ground truth:  那双扶着我不跌倒的手<UNK><UNK><UNK>
# -----------------------------------------
# epoch: 1650 loss : 1.104870
# input:  特别的怀念<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# predict:  回到童年童年童年<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# ground truth:  回到童年<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 1700 loss : 1.063321
# input:  街边的落日和小时候的复读机<UNK><UNK><UNK>
# predict:  度过了末日但我要比以前<UNK><UNK><UNK>
# ground truth:  度过了末日但我要比以前有出息<UNK>
# -----------------------------------------
# epoch: 1750 loss : 1.022710
# input:  回忆是每个人的财富<UNK><UNK><UNK><UNK>
# predict:  一定记住他他他他温柔<UNK><UNK><UNK><UNK>
# ground truth:  一定记住他<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 1800 loss : 0.983027
# input:  走尽春夏秋冬天南地北<UNK><UNK><UNK><UNK><UNK><UNK>
# predict:  母亲已经白头<UNK>白头<UNK><UNK><UNK><UNK><UNK><UNK>
# ground truth:  母亲已经白头<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 1850 loss : 0.944274
# input:  所以我努力的跑<UNK><UNK><UNK><UNK><UNK>
# predict:  把一切全部看透看透看透<UNK><UNK><UNK><UNK><UNK>
# ground truth:  把一切全部看透<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 1900 loss : 0.906455
# input:  我闭上双眼祈祷<UNK><UNK><UNK><UNK><UNK><UNK>
# predict:  我知道努力学习以后才能<UNK><UNK><UNK><UNK><UNK><UNK>
# ground truth:  我知道努力学习以后才能把歌写好<UNK><UNK>
# -----------------------------------------
# epoch: 1950 loss : 0.869580
# input:  脱掉了曾经<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# predict:  认为很时尚的<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# ground truth:  认为很时尚的大肥裤子<UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 2000 loss : 0.833663
# input:  我闭上双眼祈祷<UNK><UNK><UNK><UNK><UNK><UNK>
# predict:  我知道努力学习以后才能<UNK><UNK><UNK><UNK><UNK><UNK>
# ground truth:  我知道努力学习以后才能把歌写好<UNK><UNK>
# -----------------------------------------
# epoch: 2050 loss : 0.798718
# input:  小霸王游戏机<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# predict:  陪我度过<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# ground truth:  陪我度过了一段时期<UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 2100 loss : 0.764761
# input:  特别的怀念<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# predict:  回到童年童年童年<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# ground truth:  回到童年<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 2150 loss : 0.731806
# input:  一路走汗在流再回首已没有<UNK><UNK>
# predict:  那双扶着我不跌倒的手<UNK><UNK><UNK>
# ground truth:  那双扶着我不跌倒的手<UNK><UNK><UNK>
# -----------------------------------------
# epoch: 2200 loss : 0.699868
# input:  再没骗自己的理由<UNK><UNK><UNK><UNK><UNK>
# predict:  时间如刀不再温柔温柔如刀<UNK><UNK><UNK><UNK><UNK>
# ground truth:  时间如刀不再温柔<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 2250 loss : 0.668958
# input:  不用问我的来路<UNK><UNK><UNK><UNK><UNK>
# predict:  贫民窟的艺术家艺术家的是<UNK><UNK><UNK><UNK><UNK>
# ground truth:  贫民窟的艺术家<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 2300 loss : 0.639087
# input:  可我只能把握现在<UNK><UNK><UNK><UNK><UNK>
# predict:  带着回不去的从前从前<UNK><UNK><UNK><UNK><UNK>
# ground truth:  带着回不去的从前<UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 2350 loss : 0.610263
# input:  走尽春夏秋冬天南地北<UNK><UNK><UNK><UNK><UNK><UNK>
# predict:  母亲已经白头<UNK>白头<UNK><UNK><UNK><UNK><UNK><UNK>
# ground truth:  母亲已经白头<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 2400 loss : 0.582489
# input:  回忆是每个人的财富<UNK><UNK><UNK><UNK>
# predict:  一定记住他他他温柔很<UNK><UNK><UNK><UNK>
# ground truth:  一定记住他<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 2450 loss : 0.555769
# input:  经典的就像是oldschoolflow<UNK><UNK><UNK>
# predict:  从不用质疑质疑质疑回不去早已质疑<UNK><UNK><UNK>
# ground truth:  从不用质疑<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 2500 loss : 0.530099
# input:  那心酸的滋味我只能独自体会<UNK><UNK>
# predict:  想要回到过去但是时光不能倒退倒退倒退<UNK><UNK>
# ground truth:  想要回到过去但是时光不能倒退<UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 2550 loss : 0.505473
# input:  当我没日没夜工作从长水起飞<UNK><UNK><UNK>
# predict:  时间反复催促让我忘了疲惫<UNK><UNK><UNK>
# ground truth:  时间反复催促让我忘了疲惫<UNK><UNK><UNK>
# -----------------------------------------
# epoch: 2600 loss : 0.481882
# input:  小霸王游戏机<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# predict:  陪我度过<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# ground truth:  陪我度过了一段时期<UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 2650 loss : 0.459313
# input:  所以我努力的跑<UNK><UNK><UNK><UNK><UNK>
# predict:  把一切全部看透看透依旧<UNK><UNK><UNK><UNK><UNK>
# ground truth:  把一切全部看透<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 2700 loss : 0.437747
# input:  我渐渐长大成人<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# predict:  眼看着世界沉沦<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# ground truth:  眼看着世界沉沦<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 2750 loss : 0.417164
# input:  所以我努力的跑<UNK><UNK><UNK><UNK><UNK>
# predict:  把一切全部看透看透依旧<UNK><UNK><UNK><UNK><UNK>
# ground truth:  把一切全部看透<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 2800 loss : 0.397539
# input:  于是日复一日年复一年<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# predict:  那个美丽的春天<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# ground truth:  那个美丽的春天早已变成我的纪念<UNK><UNK>
# -----------------------------------------
# epoch: 2850 loss : 0.378846
# input:  脱掉了曾经<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# predict:  认为很时尚的<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# ground truth:  认为很时尚的大肥裤子<UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 2900 loss : 0.361056
# input:  再没骗自己的理由<UNK><UNK><UNK><UNK><UNK>
# predict:  时间如刀不再温柔温柔如刀<UNK><UNK><UNK><UNK><UNK>
# ground truth:  时间如刀不再温柔<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 2950 loss : 0.344140
# input:  校门口美味的路边摊还在不在<UNK><UNK>
# predict:  包里塞的小吃那是外婆给的<UNK><UNK>
# ground truth:  包里塞的小吃那是外婆给的爱<UNK>
# -----------------------------------------
# epoch: 3000 loss : 0.328064
# input:  我发现我早已经长大<UNK><UNK><UNK><UNK>
# predict:  我发现我早不说谎话<UNK><UNK><UNK><UNK>
# ground truth:  我发现我早不说谎话<UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 3050 loss : 0.312798
# input:  所以我努力的跑<UNK><UNK><UNK><UNK><UNK>
# predict:  把一切全部看透看透依旧<UNK><UNK><UNK><UNK><UNK>
# ground truth:  把一切全部看透<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 3100 loss : 0.298309
# input:  校门口美味的路边摊还在不在<UNK><UNK>
# predict:  包里塞的小吃那是外婆给的<UNK><UNK>
# ground truth:  包里塞的小吃那是外婆给的爱<UNK>
# -----------------------------------------
# epoch: 3150 loss : 0.284561
# input:  改变不了过去那我为了现在出征<UNK><UNK>
# predict:  我不会为了hiphop死但为了hip<UNK><UNK>
# ground truth:  我不会为了hiphop死但为了hiphop出生
# -----------------------------------------
# epoch: 3200 loss : 0.271523
# input:  那年生日同桌攒钱给我买的卡带<UNK>
# predict:  包装粗糙海报写着jay<UNK>jay<UNK>童年<UNK>
# ground truth:  包装粗糙海报写着jay<UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 3250 loss : 0.259160
# input:  于是日复一日年复一年<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# predict:  那个美丽的春天<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# ground truth:  那个美丽的春天早已变成我的纪念<UNK><UNK>
# -----------------------------------------
# epoch: 3300 loss : 0.247441
# input:  经典的就像是oldschoolflow<UNK><UNK><UNK>
# predict:  从不用质疑质疑质疑回不去早已质疑<UNK><UNK><UNK>
# ground truth:  从不用质疑<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 3350 loss : 0.236332
# input:  再没骗自己的理由<UNK><UNK><UNK><UNK><UNK>
# predict:  时间如刀不再温柔温柔<UNK><UNK><UNK><UNK><UNK><UNK>
# ground truth:  时间如刀不再温柔<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 3400 loss : 0.225803
# input:  就算我是个战神<UNK><UNK><UNK><UNK><UNK>
# predict:  可我心也一样会疼<UNK><UNK><UNK><UNK><UNK>
# ground truth:  可我心也一样会疼<UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 3450 loss : 0.215823
# input:  走尽春夏秋冬天南地北<UNK><UNK><UNK><UNK><UNK><UNK>
# predict:  母亲已经白头<UNK>白头<UNK><UNK><UNK><UNK><UNK><UNK>
# ground truth:  母亲已经白头<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 3500 loss : 0.206363
# input:  我发现我早已经长大<UNK><UNK><UNK><UNK>
# predict:  我发现我早不说谎话<UNK><UNK><UNK><UNK>
# ground truth:  我发现我早不说谎话<UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 3550 loss : 0.197394
# input:  所以我努力的跑<UNK><UNK><UNK><UNK><UNK>
# predict:  把一切全部看透看透依旧<UNK><UNK><UNK><UNK><UNK>
# ground truth:  把一切全部看透<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 3600 loss : 0.188889
# input:  我想让我爱的人过的更好
# predict:  所以才去战斗战斗战斗战斗战斗战斗战斗<UNK>
# ground truth:  所以才去战斗<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 3650 loss : 0.180825
# input:  再没骗自己的理由<UNK><UNK><UNK><UNK><UNK>
# predict:  时间如刀不再温柔温柔<UNK><UNK><UNK><UNK><UNK><UNK>
# ground truth:  时间如刀不再温柔<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 3700 loss : 0.173175
# input:  我渐渐长大成人<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# predict:  眼看着世界沉沦<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# ground truth:  眼看着世界沉沦<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 3750 loss : 0.165919
# input:  校门口美味的路边摊还在不在<UNK><UNK>
# predict:  包里塞的小吃那是外婆给的<UNK><UNK>
# ground truth:  包里塞的小吃那是外婆给的爱<UNK>
# -----------------------------------------
# epoch: 3800 loss : 0.159032
# input:  到现在<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# predict:  我依旧做<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# ground truth:  我依旧做说唱还在饿着肚子<UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 3850 loss : 0.152495
# input:  那心酸的滋味我只能独自体会<UNK><UNK>
# predict:  想要回到过去但是时光不能倒退倒退倒退<UNK><UNK>
# ground truth:  想要回到过去但是时光不能倒退<UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 3900 loss : 0.146286
# input:  那年生日同桌攒钱给我买的卡带<UNK>
# predict:  包装粗糙海报写着jay<UNK>jay<UNK>童年<UNK>
# ground truth:  包装粗糙海报写着jay<UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 3950 loss : 0.140387
# input:  于是日复一日年复一年<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# predict:  那个美丽的春天<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# ground truth:  那个美丽的春天早已变成我的纪念<UNK><UNK>
# -----------------------------------------
# epoch: 4000 loss : 0.134781
# input:  小霸王游戏机<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# predict:  陪我度过<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# ground truth:  陪我度过了一段时期<UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 4050 loss : 0.129450
# input:  小霸王游戏机<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# predict:  陪我度过<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# ground truth:  陪我度过了一段时期<UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 4100 loss : 0.124378
# input:  校门口美味的路边摊还在不在<UNK><UNK>
# predict:  包里塞的小吃那是外婆给的<UNK><UNK>
# ground truth:  包里塞的小吃那是外婆给的爱<UNK>
# -----------------------------------------
# epoch: 4150 loss : 0.119552
# input:  再没骗自己的理由<UNK><UNK><UNK><UNK><UNK>
# predict:  时间如刀不再温柔温柔<UNK><UNK><UNK><UNK><UNK><UNK>
# ground truth:  时间如刀不再温柔<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 4200 loss : 0.114957
# input:  街边的落日和小时候的复读机<UNK><UNK><UNK>
# predict:  度过了末日但我要比以前<UNK><UNK><UNK>
# ground truth:  度过了末日但我要比以前有出息<UNK>
# -----------------------------------------
# epoch: 4250 loss : 0.110580
# input:  再没骗自己的理由<UNK><UNK><UNK><UNK><UNK>
# predict:  时间如刀不再温柔温柔<UNK><UNK><UNK><UNK><UNK><UNK>
# ground truth:  时间如刀不再温柔<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 4300 loss : 0.106408
# input:  回忆是每个人的财富<UNK><UNK><UNK><UNK>
# predict:  一定记住他他他温柔很<UNK><UNK><UNK><UNK>
# ground truth:  一定记住他<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 4350 loss : 0.102431
# input:  所以我努力的跑<UNK><UNK><UNK><UNK><UNK>
# predict:  把一切全部看透看透依旧<UNK><UNK><UNK><UNK><UNK>
# ground truth:  把一切全部看透<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 4400 loss : 0.098637
# input:  改变不了过去那我为了现在出征<UNK><UNK>
# predict:  我不会为了hiphop死但为了hip<UNK><UNK>
# ground truth:  我不会为了hiphop死但为了hiphop出生
# -----------------------------------------
# epoch: 4450 loss : 0.095017
# input:  脱掉了曾经<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# predict:  认为很时尚的<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# ground truth:  认为很时尚的大肥裤子<UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 4500 loss : 0.091561
# input:  到现在<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# predict:  我依旧做<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# ground truth:  我依旧做说唱还在饿着肚子<UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 4550 loss : 0.088260
# input:  我也不再年幼<UNK><UNK><UNK><UNK><UNK><UNK>
# predict:  那些年做过的<UNK><UNK><UNK><UNK><UNK><UNK>
# ground truth:  那些年做过的课间操<UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 4600 loss : 0.085105
# input:  回忆是每个人的财富<UNK><UNK><UNK><UNK>
# predict:  一定记住他他他温柔很<UNK><UNK><UNK><UNK>
# ground truth:  一定记住他<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 4650 loss : 0.082089
# input:  经典的就像是oldschoolflow<UNK><UNK><UNK>
# predict:  从不用质疑质疑质疑回不去早已质疑<UNK><UNK><UNK>
# ground truth:  从不用质疑<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 4700 loss : 0.079204
# input:  校门口美味的路边摊还在不在<UNK><UNK>
# predict:  包里塞的小吃那是外婆给的<UNK><UNK>
# ground truth:  包里塞的小吃那是外婆给的爱<UNK>
# -----------------------------------------
# epoch: 4750 loss : 0.076444
# input:  小霸王游戏机<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# predict:  陪我度过<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# ground truth:  陪我度过了一段时期<UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 4800 loss : 0.073801
# input:  那心酸的滋味我只能独自体会<UNK><UNK>
# predict:  想要回到过去但是时光不能倒退倒退倒退<UNK><UNK>
# ground truth:  想要回到过去但是时光不能倒退<UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 4850 loss : 0.071271
# input:  特别的怀念<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# predict:  回到童年<UNK>知道<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# ground truth:  回到童年<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 4900 loss : 0.068846
# input:  我发现我早已经长大<UNK><UNK><UNK><UNK>
# predict:  我发现我早不说谎话<UNK><UNK><UNK><UNK>
# ground truth:  我发现我早不说谎话<UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 4950 loss : 0.066522
# input:  当我没日没夜工作从长水起飞<UNK><UNK><UNK>
# predict:  时间反复催促让我忘了疲惫<UNK><UNK><UNK>
# ground truth:  时间反复催促让我忘了疲惫<UNK><UNK><UNK>
# -----------------------------------------
# epoch: 5000 loss : 0.064294
# input:  不用问我的来路<UNK><UNK><UNK><UNK><UNK>
# predict:  贫民窟的艺术家的艺术家的<UNK><UNK><UNK><UNK><UNK>
# ground truth:  贫民窟的艺术家<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 5050 loss : 0.062157
# input:  我也不再年幼<UNK><UNK><UNK><UNK><UNK><UNK>
# predict:  那些年做过的<UNK><UNK><UNK><UNK><UNK><UNK>
# ground truth:  那些年做过的课间操<UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 5100 loss : 0.060105
# input:  走尽春夏秋冬天南地北<UNK><UNK><UNK><UNK><UNK><UNK>
# predict:  母亲已经白头<UNK>白头<UNK><UNK><UNK><UNK><UNK><UNK>
# ground truth:  母亲已经白头<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 5150 loss : 0.058136
# input:  街边的落日和小时候的复读机<UNK><UNK><UNK>
# predict:  度过了末日但我要比以前<UNK><UNK><UNK>
# ground truth:  度过了末日但我要比以前有出息<UNK>
# -----------------------------------------
# epoch: 5200 loss : 0.056245
# input:  于是日复一日年复一年<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# predict:  那个美丽的春天<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# ground truth:  那个美丽的春天早已变成我的纪念<UNK><UNK>
# -----------------------------------------
# epoch: 5250 loss : 0.054428
# input:  课桌上面摆着老师送的铅笔刀<UNK><UNK><UNK>
# predict:  她教我如何起跑起跑起跑是质疑是<UNK><UNK><UNK>
# ground truth:  她教我如何起跑<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 5300 loss : 0.052681
# input:  经典的就像是oldschoolflow<UNK><UNK><UNK>
# predict:  从不用质疑质疑质疑回不去早已质疑<UNK><UNK><UNK>
# ground truth:  从不用质疑<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 5350 loss : 0.051002
# input:  不用问我的来路<UNK><UNK><UNK><UNK><UNK>
# predict:  贫民窟的艺术家的艺术家的<UNK><UNK><UNK><UNK><UNK>
# ground truth:  贫民窟的艺术家<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 5400 loss : 0.049388
# input:  于是日复一日年复一年<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# predict:  那个美丽的春天<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# ground truth:  那个美丽的春天早已变成我的纪念<UNK><UNK>
# -----------------------------------------
# epoch: 5450 loss : 0.047834
# input:  我也不再年幼<UNK><UNK><UNK><UNK><UNK><UNK>
# predict:  那些年做过的<UNK><UNK><UNK><UNK><UNK><UNK>
# ground truth:  那些年做过的课间操<UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 5500 loss : 0.046339
# input:  改变不了过去那我为了现在出征<UNK><UNK>
# predict:  我不会为了hiphop死但为了hip<UNK><UNK>
# ground truth:  我不会为了hiphop死但为了hiphop出生
# -----------------------------------------
# epoch: 5550 loss : 0.044899
# input:  我闭上双眼祈祷<UNK><UNK><UNK><UNK><UNK><UNK>
# predict:  我知道努力学习以后才能<UNK><UNK><UNK><UNK><UNK><UNK>
# ground truth:  我知道努力学习以后才能把歌写好<UNK><UNK>
# -----------------------------------------
# epoch: 5600 loss : 0.043513
# input:  一路走汗在流再回首已没有<UNK><UNK>
# predict:  那双扶着我不跌倒的手<UNK><UNK><UNK>
# ground truth:  那双扶着我不跌倒的手<UNK><UNK><UNK>
# -----------------------------------------
# epoch: 5650 loss : 0.042177
# input:  经典的就像是oldschoolflow<UNK><UNK><UNK>
# predict:  从不用质疑质疑质疑回不去早已质疑<UNK><UNK><UNK>
# ground truth:  从不用质疑<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 5700 loss : 0.040890
# input:  回忆是每个人的财富<UNK><UNK><UNK><UNK>
# predict:  一定记住他他他温柔粗糙<UNK><UNK><UNK><UNK>
# ground truth:  一定记住他<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 5750 loss : 0.039650
# input:  校门口美味的路边摊还在不在<UNK><UNK>
# predict:  包里塞的小吃那是外婆给的<UNK><UNK>
# ground truth:  包里塞的小吃那是外婆给的爱<UNK>
# -----------------------------------------
# epoch: 5800 loss : 0.038453
# input:  不用问我的来路<UNK><UNK><UNK><UNK><UNK>
# predict:  贫民窟的艺术家艺术家的艺术家<UNK><UNK><UNK><UNK><UNK>
# ground truth:  贫民窟的艺术家<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 5850 loss : 0.037299
# input:  脱掉了曾经<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# predict:  认为很时尚的<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# ground truth:  认为很时尚的大肥裤子<UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 5900 loss : 0.036186
# input:  到现在<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# predict:  我依旧做<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# ground truth:  我依旧做说唱还在饿着肚子<UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 5950 loss : 0.035112
# input:  我闭上双眼祈祷<UNK><UNK><UNK><UNK><UNK><UNK>
# predict:  我知道努力学习以后才能<UNK><UNK><UNK><UNK><UNK><UNK>
# ground truth:  我知道努力学习以后才能把歌写好<UNK><UNK>
# -----------------------------------------
# epoch: 6000 loss : 0.034075
# input:  不用问我的来路<UNK><UNK><UNK><UNK><UNK>
# predict:  贫民窟的艺术家艺术家的艺术家<UNK><UNK><UNK><UNK><UNK>
# ground truth:  贫民窟的艺术家<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 6050 loss : 0.033074
# input:  那心酸的滋味我只能独自体会<UNK><UNK>
# predict:  想要回到过去但是时光不能倒退倒退倒退<UNK><UNK>
# ground truth:  想要回到过去但是时光不能倒退<UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 6100 loss : 0.032107
# input:  经典的就像是oldschoolflow<UNK><UNK><UNK>
# predict:  从不用质疑质疑质疑回不去早已质疑<UNK><UNK><UNK>
# ground truth:  从不用质疑<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 6150 loss : 0.031172
# input:  当我没日没夜工作从长水起飞<UNK><UNK><UNK>
# predict:  时间反复催促让我忘了疲惫<UNK><UNK><UNK>
# ground truth:  时间反复催促让我忘了疲惫<UNK><UNK><UNK>
# -----------------------------------------
# epoch: 6200 loss : 0.030269
# input:  再没骗自己的理由<UNK><UNK><UNK><UNK><UNK>
# predict:  时间如刀不再温柔温柔<UNK><UNK><UNK><UNK><UNK><UNK>
# ground truth:  时间如刀不再温柔<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 6250 loss : 0.029396
# input:  到现在<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# predict:  我依旧做<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# ground truth:  我依旧做说唱还在饿着肚子<UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 6300 loss : 0.028552
# input:  小霸王游戏机<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# predict:  陪我度过<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# ground truth:  陪我度过了一段时期<UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 6350 loss : 0.027737
# input:  再没骗自己的理由<UNK><UNK><UNK><UNK><UNK>
# predict:  时间如刀不再温柔温柔<UNK><UNK><UNK><UNK><UNK><UNK>
# ground truth:  时间如刀不再温柔<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 6400 loss : 0.026947
# input:  课桌上面摆着老师送的铅笔刀<UNK><UNK><UNK>
# predict:  她教我如何起跑起跑起跑是质疑疼<UNK><UNK><UNK>
# ground truth:  她教我如何起跑<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 6450 loss : 0.026184
# input:  可我只能把握现在<UNK><UNK><UNK><UNK><UNK>
# predict:  带着回不去的从前jay<UNK><UNK><UNK><UNK><UNK>
# ground truth:  带着回不去的从前<UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 6500 loss : 0.025445
# input:  我闭上双眼祈祷<UNK><UNK><UNK><UNK><UNK><UNK>
# predict:  我知道努力学习以后才能<UNK><UNK><UNK><UNK><UNK><UNK>
# ground truth:  我知道努力学习以后才能把歌写好<UNK><UNK>
# -----------------------------------------
# epoch: 6550 loss : 0.024730
# input:  我想让我爱的人过的更好
# predict:  所以才去战斗战斗战斗战斗战斗战斗战斗<UNK>
# ground truth:  所以才去战斗<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 6600 loss : 0.024038
# input:  走尽春夏秋冬天南地北<UNK><UNK><UNK><UNK><UNK><UNK>
# predict:  母亲已经白头<UNK>白头<UNK><UNK><UNK><UNK><UNK><UNK>
# ground truth:  母亲已经白头<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 6650 loss : 0.023368
# input:  我想让我爱的人过的更好
# predict:  所以才去战斗战斗战斗战斗战斗战斗战斗<UNK>
# ground truth:  所以才去战斗<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 6700 loss : 0.022719
# input:  所以我努力的跑<UNK><UNK><UNK><UNK><UNK>
# predict:  把一切全部看透看透出生<UNK><UNK><UNK><UNK><UNK>
# ground truth:  把一切全部看透<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 6750 loss : 0.022090
# input:  再没骗自己的理由<UNK><UNK><UNK><UNK><UNK>
# predict:  时间如刀不再温柔温柔<UNK><UNK><UNK><UNK><UNK><UNK>
# ground truth:  时间如刀不再温柔<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 6800 loss : 0.021481
# input:  所以我努力的跑<UNK><UNK><UNK><UNK><UNK>
# predict:  把一切全部看透看透出生<UNK><UNK><UNK><UNK><UNK>
# ground truth:  把一切全部看透<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 6850 loss : 0.020890
# input:  于是日复一日年复一年<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# predict:  那个美丽的春天<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# ground truth:  那个美丽的春天早已变成我的纪念<UNK><UNK>
# -----------------------------------------
# epoch: 6900 loss : 0.020318
# input:  所以我努力的跑<UNK><UNK><UNK><UNK><UNK>
# predict:  把一切全部看透看透出生<UNK><UNK><UNK><UNK><UNK>
# ground truth:  把一切全部看透<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 6950 loss : 0.019764
# input:  特别的怀念<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# predict:  回到童年<UNK>知道<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# ground truth:  回到童年<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 7000 loss : 0.019227
# input:  所以我努力的跑<UNK><UNK><UNK><UNK><UNK>
# predict:  把一切全部看透看透出生<UNK><UNK><UNK><UNK><UNK>
# ground truth:  把一切全部看透<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 7050 loss : 0.018705
# input:  小霸王游戏机<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# predict:  陪我度过<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# ground truth:  陪我度过了一段时期<UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 7100 loss : 0.018200
# input:  那年生日同桌攒钱给我买的卡带<UNK>
# predict:  包装粗糙海报写着jay<UNK>jay<UNK>度过<UNK>
# ground truth:  包装粗糙海报写着jay<UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 7150 loss : 0.017710
# input:  于是日复一日年复一年<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# predict:  那个美丽的春天<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# ground truth:  那个美丽的春天早已变成我的纪念<UNK><UNK>
# -----------------------------------------
# epoch: 7200 loss : 0.017234
# input:  特别的怀念<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# predict:  回到童年<UNK>知道<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# ground truth:  回到童年<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 7250 loss : 0.016772
# input:  可我只能把握现在<UNK><UNK><UNK><UNK><UNK>
# predict:  带着回不去的从前jay<UNK><UNK><UNK><UNK><UNK>
# ground truth:  带着回不去的从前<UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 7300 loss : 0.016325
# input:  到现在<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# predict:  我依旧做<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# ground truth:  我依旧做说唱还在饿着肚子<UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 7350 loss : 0.015890
# input:  我想让我爱的人过的更好
# predict:  所以才去战斗战斗战斗战斗战斗战斗战斗<UNK>
# ground truth:  所以才去战斗<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 7400 loss : 0.015468
# input:  经典的就像是oldschoolflow<UNK><UNK><UNK>
# predict:  从不用质疑质疑回不去早已质疑回不去<UNK><UNK><UNK>
# ground truth:  从不用质疑<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 7450 loss : 0.015059
# input:  课桌上面摆着老师送的铅笔刀<UNK><UNK><UNK>
# predict:  她教我如何起跑起跑起跑是质疑疼<UNK><UNK><UNK>
# ground truth:  她教我如何起跑<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 7500 loss : 0.014661
# input:  经典的就像是oldschoolflow<UNK><UNK><UNK>
# predict:  从不用质疑质疑回不去早已质疑回不去<UNK><UNK><UNK>
# ground truth:  从不用质疑<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 7550 loss : 0.014275
# input:  当我没日没夜工作从长水起飞<UNK><UNK><UNK>
# predict:  时间反复催促让我忘了疲惫<UNK><UNK><UNK>
# ground truth:  时间反复催促让我忘了疲惫<UNK><UNK><UNK>
# -----------------------------------------
# epoch: 7600 loss : 0.013900
# input:  校门口美味的路边摊还在不在<UNK><UNK>
# predict:  包里塞的小吃那是外婆给的<UNK><UNK>
# ground truth:  包里塞的小吃那是外婆给的爱<UNK>
# -----------------------------------------
# epoch: 7650 loss : 0.013536
# input:  到现在<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# predict:  我依旧做<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# ground truth:  我依旧做说唱还在饿着肚子<UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 7700 loss : 0.013182
# input:  我也不再年幼<UNK><UNK><UNK><UNK><UNK><UNK>
# predict:  那些年做过的<UNK><UNK><UNK><UNK><UNK><UNK>
# ground truth:  那些年做过的课间操<UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 7750 loss : 0.012838
# input:  课桌上面摆着老师送的铅笔刀<UNK><UNK><UNK>
# predict:  她教我如何起跑起跑起跑是质疑疼<UNK><UNK><UNK>
# ground truth:  她教我如何起跑<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 7800 loss : 0.012504
# input:  走尽春夏秋冬天南地北<UNK><UNK><UNK><UNK><UNK><UNK>
# predict:  母亲已经白头<UNK>白头<UNK><UNK><UNK><UNK><UNK><UNK>
# ground truth:  母亲已经白头<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 7850 loss : 0.012179
# input:  特别的怀念<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# predict:  回到童年<UNK>知道<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# ground truth:  回到童年<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 7900 loss : 0.011864
# input:  到现在<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# predict:  我依旧做<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# ground truth:  我依旧做说唱还在饿着肚子<UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 7950 loss : 0.011557
# input:  课桌上面摆着老师送的铅笔刀<UNK><UNK><UNK>
# predict:  她教我如何起跑起跑起跑是质疑疼<UNK><UNK><UNK>
# ground truth:  她教我如何起跑<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 8000 loss : 0.011259
# input:  小霸王游戏机<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# predict:  陪我度过<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# ground truth:  陪我度过了一段时期<UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 8050 loss : 0.010969
# input:  所以我努力的跑<UNK><UNK><UNK><UNK><UNK>
# predict:  把一切全部看透看透从前<UNK><UNK><UNK><UNK><UNK>
# ground truth:  把一切全部看透<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 8100 loss : 0.010688
# input:  脱掉了曾经<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# predict:  认为很时尚的<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# ground truth:  认为很时尚的大肥裤子<UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 8150 loss : 0.010414
# input:  当我没日没夜工作从长水起飞<UNK><UNK><UNK>
# predict:  时间反复催促让我忘了疲惫<UNK><UNK><UNK>
# ground truth:  时间反复催促让我忘了疲惫<UNK><UNK><UNK>
# -----------------------------------------
# epoch: 8200 loss : 0.010147
# input:  校门口美味的路边摊还在不在<UNK><UNK>
# predict:  包里塞的小吃那是外婆给的<UNK><UNK>
# ground truth:  包里塞的小吃那是外婆给的爱<UNK>
# -----------------------------------------
# epoch: 8250 loss : 0.009888
# input:  校门口美味的路边摊还在不在<UNK><UNK>
# predict:  包里塞的小吃那是外婆给的<UNK><UNK>
# ground truth:  包里塞的小吃那是外婆给的爱<UNK>
# -----------------------------------------
# epoch: 8300 loss : 0.009636
# input:  于是日复一日年复一年<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# predict:  那个美丽的春天<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# ground truth:  那个美丽的春天早已变成我的纪念<UNK><UNK>
# -----------------------------------------
# epoch: 8350 loss : 0.009391
# input:  脱掉了曾经<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# predict:  认为很时尚的<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# ground truth:  认为很时尚的大肥裤子<UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 8400 loss : 0.009153
# input:  校门口美味的路边摊还在不在<UNK><UNK>
# predict:  包里塞的小吃那是外婆给的<UNK><UNK>
# ground truth:  包里塞的小吃那是外婆给的爱<UNK>
# -----------------------------------------
# epoch: 8450 loss : 0.008921
# input:  街边的落日和小时候的复读机<UNK><UNK><UNK>
# predict:  度过了末日但我要比以前<UNK><UNK><UNK>
# ground truth:  度过了末日但我要比以前有出息<UNK>
# -----------------------------------------
# epoch: 8500 loss : 0.008695
# input:  我发现我早已经长大<UNK><UNK><UNK><UNK>
# predict:  我发现我早不说谎话<UNK><UNK><UNK><UNK>
# ground truth:  我发现我早不说谎话<UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 8550 loss : 0.008476
# input:  脱掉了曾经<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# predict:  认为很时尚的<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# ground truth:  认为很时尚的大肥裤子<UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 8600 loss : 0.008262
# input:  我闭上双眼祈祷<UNK><UNK><UNK><UNK><UNK><UNK>
# predict:  我知道努力学习以后才能<UNK><UNK><UNK><UNK><UNK><UNK>
# ground truth:  我知道努力学习以后才能把歌写好<UNK><UNK>
# -----------------------------------------
# epoch: 8650 loss : 0.008054
# input:  一路走汗在流再回首已没有<UNK><UNK>
# predict:  那双扶着我不跌倒的手<UNK><UNK><UNK>
# ground truth:  那双扶着我不跌倒的手<UNK><UNK><UNK>
# -----------------------------------------
# epoch: 8700 loss : 0.007852
# input:  经典的就像是oldschoolflow<UNK><UNK><UNK>
# predict:  从不用质疑质疑回不去早已质疑回不去<UNK><UNK><UNK>
# ground truth:  从不用质疑<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 8750 loss : 0.007655
# input:  脱掉了曾经<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# predict:  认为很时尚的<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# ground truth:  认为很时尚的大肥裤子<UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 8800 loss : 0.007463
# input:  当我没日没夜工作从长水起飞<UNK><UNK><UNK>
# predict:  时间反复催促让我忘了疲惫<UNK><UNK><UNK>
# ground truth:  时间反复催促让我忘了疲惫<UNK><UNK><UNK>
# -----------------------------------------
# epoch: 8850 loss : 0.007276
# input:  课桌上面摆着老师送的铅笔刀<UNK><UNK><UNK>
# predict:  她教我如何起跑起跑起跑是质疑疼<UNK><UNK><UNK>
# ground truth:  她教我如何起跑<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 8900 loss : 0.007094
# input:  所以我努力的跑<UNK><UNK><UNK><UNK><UNK>
# predict:  把一切全部看透看透从前<UNK><UNK><UNK><UNK><UNK>
# ground truth:  把一切全部看透<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 8950 loss : 0.006918
# input:  我发现我早已经长大<UNK><UNK><UNK><UNK>
# predict:  我发现我早不说谎话<UNK><UNK><UNK><UNK>
# ground truth:  我发现我早不说谎话<UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 9000 loss : 0.006745
# input:  我闭上双眼祈祷<UNK><UNK><UNK><UNK><UNK><UNK>
# predict:  我知道努力学习以后才能<UNK><UNK><UNK><UNK><UNK><UNK>
# ground truth:  我知道努力学习以后才能把歌写好<UNK><UNK>
# -----------------------------------------
# epoch: 9050 loss : 0.006577
# input:  小霸王游戏机<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# predict:  陪我度过<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# ground truth:  陪我度过了一段时期<UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 9100 loss : 0.006414
# input:  校门口美味的路边摊还在不在<UNK><UNK>
# predict:  包里塞的小吃那是外婆给的<UNK><UNK>
# ground truth:  包里塞的小吃那是外婆给的爱<UNK>
# -----------------------------------------
# epoch: 9150 loss : 0.006255
# input:  改变不了过去那我为了现在出征<UNK><UNK>
# predict:  我不会为了hiphop死但为了hip<UNK><UNK>
# ground truth:  我不会为了hiphop死但为了hiphop出生
# -----------------------------------------
# epoch: 9200 loss : 0.006100
# input:  小霸王游戏机<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# predict:  陪我度过<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# ground truth:  陪我度过了一段时期<UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 9250 loss : 0.005949
# input:  校门口美味的路边摊还在不在<UNK><UNK>
# predict:  包里塞的小吃那是外婆给的<UNK><UNK>
# ground truth:  包里塞的小吃那是外婆给的爱<UNK>
# -----------------------------------------
# epoch: 9300 loss : 0.005802
# input:  那年生日同桌攒钱给我买的卡带<UNK>
# predict:  包装粗糙海报写着jay<UNK>jay<UNK>度过<UNK>
# ground truth:  包装粗糙海报写着jay<UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 9350 loss : 0.005659
# input:  当我没日没夜工作从长水起飞<UNK><UNK><UNK>
# predict:  时间反复催促让我忘了疲惫<UNK><UNK><UNK>
# ground truth:  时间反复催促让我忘了疲惫<UNK><UNK><UNK>
# -----------------------------------------
# epoch: 9400 loss : 0.005519
# input:  经典的就像是oldschoolflow<UNK><UNK><UNK>
# predict:  从不用质疑质疑回不去早已质疑回不去<UNK><UNK><UNK>
# ground truth:  从不用质疑<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 9450 loss : 0.005383
# input:  当我没日没夜工作从长水起飞<UNK><UNK><UNK>
# predict:  时间反复催促让我忘了疲惫<UNK><UNK><UNK>
# ground truth:  时间反复催促让我忘了疲惫<UNK><UNK><UNK>
# -----------------------------------------
# epoch: 9500 loss : 0.005251
# input:  一路走汗在流再回首已没有<UNK><UNK>
# predict:  那双扶着我不跌倒的手<UNK><UNK><UNK>
# ground truth:  那双扶着我不跌倒的手<UNK><UNK><UNK>
# -----------------------------------------
# epoch: 9550 loss : 0.005122
# input:  那年生日同桌攒钱给我买的卡带<UNK>
# predict:  包装粗糙海报写着jay<UNK>jay<UNK>度过<UNK>
# ground truth:  包装粗糙海报写着jay<UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 9600 loss : 0.004996
# input:  可我只能把握现在<UNK><UNK><UNK><UNK><UNK>
# predict:  带着回不去的从前jay<UNK><UNK><UNK><UNK><UNK>
# ground truth:  带着回不去的从前<UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 9650 loss : 0.004873
# input:  那心酸的滋味我只能独自体会<UNK><UNK>
# predict:  想要回到过去但是时光不能倒退倒退<UNK><UNK><UNK>
# ground truth:  想要回到过去但是时光不能倒退<UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 9700 loss : 0.004754
# input:  不用问我的来路<UNK><UNK><UNK><UNK><UNK>
# predict:  贫民窟的艺术家艺术家的艺术家<UNK><UNK><UNK><UNK><UNK>
# ground truth:  贫民窟的艺术家<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 9750 loss : 0.004637
# input:  当我没日没夜工作从长水起飞<UNK><UNK><UNK>
# predict:  时间反复催促让我忘了疲惫<UNK><UNK><UNK>
# ground truth:  时间反复催促让我忘了疲惫<UNK><UNK><UNK>
# -----------------------------------------
# epoch: 9800 loss : 0.004524
# input:  我发现我早已经长大<UNK><UNK><UNK><UNK>
# predict:  我发现我早不说谎话<UNK><UNK><UNK><UNK>
# ground truth:  我发现我早不说谎话<UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 9850 loss : 0.004413
# input:  课桌上面摆着老师送的铅笔刀<UNK><UNK><UNK>
# predict:  她教我如何起跑起跑起跑质疑疼疼<UNK><UNK><UNK>
# ground truth:  她教我如何起跑<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 9900 loss : 0.004306
# input:  特别的怀念<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# predict:  回到童年<UNK>知道<UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# ground truth:  回到童年<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# -----------------------------------------
# epoch: 9950 loss : 0.004201
# input:  街边的落日和小时候的复读机<UNK><UNK><UNK>
# predict:  度过了末日但我要比以前<UNK><UNK><UNK>
# ground truth:  度过了末日但我要比以前有出息<UNK>
# -----------------------------------------
